# %%
# Fetch the full Basic Law text for training data
import requests

url = "https://www.constituteproject.org/constitution/Palestine_2005.pdf"
# Or scrape the HTML version at palestinianbasiclaw.org
